# %%
import numpy as np
# %matplotlib inline 
import pandas as pd
import tensorflow as tf
from IPython.display import display, Image
import cv2
from PIL import Image
from tqdm import tqdm
from keras.applications.vgg19 import VGG19
from keras.utils.vis_utils import plot_model
import gc
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# let's load the dataset
df = pd.read_excel("./KSA_test.xlsx")
df.drop('Response Time', inplace=True, axis=1)
df.drop('Class Name', inplace=True, axis=1)
df.plot(figsize=(16,8))
plt.show()

# %%
# create train test split
train_length = round(len(df)*0.8)
test_length = len(df) - train_length
train = df.iloc[0:train_length]
test = df.iloc[train_length:]

# %%
# let's scale the values of the dataset
scaler = MinMaxScaler(feature_range = (0,1))
train_scaled = pd.DataFrame(scaler.fit_transform(train), columns=df.columns)
test_scaled = pd.DataFrame(scaler.fit_transform(test), columns=df.columns)

# %%
def train_generator(dataset, n_lags=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - n_lags - 1):
        a = dataset.iloc[i:(i+n_lags)].to_numpy()
        dataX.append(a)
        dataY.append(dataset.iloc[i + n_lags].to_numpy())
    return (np.array(dataX), np.array(dataY))

# %%
TIME_STEPS = 50
X_train, y_train = train_generator(train_scaled, n_lags = TIME_STEPS)
X_test_scaled, y_test_scaled = train_generator(test_scaled, n_lags=TIME_STEPS)
X_test, y_test = train_generator(test, n_lags=TIME_STEPS)

# %%
print(X_train.shape)
# Out:
# (1890, 50, 1)

# %% [markdown]
# # Let's build a dense network and test it out

# %%
# define the keras model
model_NN = tf.keras.Sequential()
model_NN.add(tf.keras.layers.Dense(32, input_dim=50, activation='relu'))
model_NN.add(tf.keras.layers.Dense(32, activation='relu'))
model_NN.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
model_NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1632
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,721
# Trainable params: 2,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_NN.compile(loss="mean_absolute_error", optimizer= tf.keras.optimizers.Adam())

# %%
es = tf.keras.callbacks.EarlyStopping( monitor='val_loss', patience=8, verbose=1, restore_best_weights=True)
lr_red = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1, min_lr=0.0000001,)

# %%
callbacks = [es, lr_red]
history = model_NN.fit(X_train, y_train, epochs=200, validation_split=0.25, batch_size=256, verbose=1,
                    shuffle=False,
                    callbacks = callbacks)
# would be logical to train model on mutltiple batch sizes
# Out:
# Epoch 1/200
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1857 - val_loss: 0.1367 - lr: 0.0010
# Epoch 2/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1679 - val_loss: 0.1129 - lr: 0.0010
# Epoch 3/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1610 - val_loss: 0.1035 - lr: 0.0010
# Epoch 4/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1581 - val_loss: 0.0998 - lr: 0.0010
# Epoch 5/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1559 - val_loss: 0.0983 - lr: 0.0010
# Epoch 6/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1536 - val_loss: 0.0982 - lr: 0.0010
# Epoch 7/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1512 - val_loss: 0.0987 - lr: 0.0010
# Epoch 8/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1492 - val_loss: 0.0990 - lr: 0.0010
# Epoch 9/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1472 - val_loss: 0.0986 - lr: 0.0010
# Epoch 10/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1453 - val_loss: 0.0977 - lr: 0.0010
# Epoch 11/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1433 - val_loss: 0.0967 - lr: 0.0010
# Epoch 12/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1411 - val_loss: 0.0953 - lr: 0.0010
# Epoch 13/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1388 - val_loss: 0.0936 - lr: 0.0010
# Epoch 14/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1365 - val_loss: 0.0917 - lr: 0.0010
# Epoch 15/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1340 - val_loss: 0.0903 - lr: 0.0010
# Epoch 16/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1315 - val_loss: 0.0896 - lr: 0.0010
# Epoch 17/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1291 - val_loss: 0.0890 - lr: 0.0010
# Epoch 18/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1267 - val_loss: 0.0883 - lr: 0.0010
# Epoch 19/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1242 - val_loss: 0.0874 - lr: 0.0010
# Epoch 20/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1217 - val_loss: 0.0865 - lr: 0.0010
# Epoch 21/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1191 - val_loss: 0.0855 - lr: 0.0010
# Epoch 22/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1165 - val_loss: 0.0844 - lr: 0.0010
# Epoch 23/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1140 - val_loss: 0.0837 - lr: 0.0010
# Epoch 24/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1113 - val_loss: 0.0834 - lr: 0.0010
# Epoch 25/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1089 - val_loss: 0.0826 - lr: 0.0010
# Epoch 26/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1065 - val_loss: 0.0816 - lr: 0.0010
# Epoch 27/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1039 - val_loss: 0.0813 - lr: 0.0010
# Epoch 28/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.
200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0629 - val_loss: 0.0632 - lr: 0.0010
# Epoch 80/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0631 - val_loss: 0.0633 - lr: 0.0010
# Epoch 81/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0635 - val_loss: 0.0640 - lr: 0.0010
# Epoch 82/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0626 - val_loss: 0.0637 - lr: 0.0010
# Epoch 83/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0621 - val_loss: 0.0631 - lr: 0.0010
# Epoch 84/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0620 - val_loss: 0.0628 - lr: 0.0010
# Epoch 85/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0624 - val_loss: 0.0626 - lr: 0.0010
# Epoch 86/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0629 - val_loss: 0.0634 - lr: 0.0010
# Epoch 87/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0618 - val_loss: 0.0634 - lr: 0.0010
# Epoch 88/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0613 - val_loss: 0.0629 - lr: 0.0010
# Epoch 89/200
# 1/6 [====>.........................] - ETA: 0s - loss: 0.0690
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0615 - val_loss: 0.0626 - lr: 0.0010
# Epoch 90/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0617 - val_loss: 0.0627 - lr: 2.0000e-04
# Epoch 91/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0613 - val_loss: 0.0627 - lr: 2.0000e-04
# Epoch 92/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0610 - val_loss: 0.0624 - lr: 2.0000e-04
# Epoch 93/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0610 - val_loss: 0.0626 - lr: 2.0000e-04
# Epoch 94/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0609 - val_loss: 0.0625 - lr: 2.0000e-04
# Epoch 95/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0609 - val_loss: 0.0625 - lr: 2.0000e-04
# Epoch 96/200
# 1/6 [====>.........................] - ETA: 0s - loss: 0.0684
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0624 - lr: 2.0000e-04
# Epoch 97/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0624 - lr: 4.0000e-05
# Epoch 98/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0624 - lr: 4.0000e-05
# Epoch 99/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0624 - lr: 4.0000e-05
# Epoch 100/200
# 1/6 [====>.........................] - ETA: 0s - loss: 0.0684
# Epoch 00100: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0624 - lr: 4.0000e-05
# Epoch 101/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0608 - val_loss: 0.0624 - lr: 8.0000e-06
# Epoch 102/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0607 - val_loss: 0.0624 - lr: 8.0000e-06
# Epoch 103/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0607 - val_loss: 0.0624 - lr: 8.0000e-06
# Epoch 104/200
# 1/6 [====>.........................] - ETA: 0s - loss: 0.0684
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0607 - val_loss: 0.0624 - lr: 8.0000e-06
# Epoch 105/200
# 1/6 [====>.........................] - ETA: 0s - loss: 0.0684Restoring model weights from the end of the best epoch: 97.
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0607 - val_loss: 0.0624 - lr: 1.6000e-06
# Epoch 00105: early stopping

# %%
# sayyiv le modele when done
model_NN.save('./test_model_NN')
# Out:
# INFO:tensorflow:Assets written to: ./test_model_NN\assets

# %%
preds = model_NN.predict(X_test_scaled)
preds = scaler.inverse_transform(preds)
plt.rcParams["figure.figsize"] = (32,12)
TestY = pd.DataFrame(y_test, columns=['avg_cpu'])
PredY = pd.DataFrame(preds, columns=['avg_cpu'])

plot_avg = plt.figure(1)
plt.plot(TestY['avg_cpu'])
plt.plot(PredY['avg_cpu'])
plt.show()

# %%
#-----------------------------------------------------------
# LETS CHECK HOW GOOD THE MODEL PERFORMED
#-----------------------------------------------------------
testScore_1 = math.sqrt(mean_squared_error(y_test[:], preds[:]))
print('Test Score: %.2f RMSE' % (testScore_1))

testScore_2 = math.sqrt(mean_absolute_error(y_test[:], preds[:]))
print('Test Score: %f MAE' % (testScore_2))

testScore_3 = np.mean(np.abs(preds - y_test)/np.abs(y_test)*100)
print('Test Score: %f MAPE' % (testScore_3))
# Out:
# Test Score: 0.05 RMSE
# Test Score: 0.191858 MAE
# Test Score: 33.679345 MAPE

# %% [markdown]
# # Let's build an LSTM model

# %%
# let's build the lstm model
model_lstm = tf.keras.models.Sequential()
model_lstm.add(tf.keras.layers.LSTM(512,input_shape=(X_train.shape[1], X_train.shape[2]),return_sequences=True))
model_lstm.add(tf.keras.layers.LSTM(512, return_sequences=False))
model_lstm.add(tf.keras.layers.Dense(1))
model_lstm.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 512)           1052672
#
#  lstm_1 (LSTM)               (None, 512)               2099200
#
#  dense_3 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 3,152,385
# Trainable params: 3,152,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_lstm.compile(loss="mean_absolute_error", optimizer= tf.keras.optimizers.Adam())

# %%
es = tf.keras.callbacks.EarlyStopping( monitor='val_loss', patience=8, verbose=1, restore_best_weights=True)
lr_red = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1, min_lr=0.0000001,)

# %%
callbacks = [es, lr_red]
history = model_lstm.fit(X_train, y_train, epochs=100, validation_split=0.25, batch_size=256, verbose=1,
                    shuffle=False,
                    callbacks = callbacks)
# would be logical to train model on mutltiple batch sizes
# Out:
# Epoch 1/100
# 6/6 [==============================] - 11s 2s/step - loss: 0.1409 - val_loss: 0.1092 - lr: 0.0010
# Epoch 2/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.1285 - val_loss: 0.1240 - lr: 0.0010
# Epoch 3/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.1122 - val_loss: 0.0889 - lr: 0.0010
# Epoch 4/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0924 - val_loss: 0.0880 - lr: 0.0010
# Epoch 5/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0944 - val_loss: 0.0890 - lr: 0.0010
# Epoch 6/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0900 - val_loss: 0.0852 - lr: 0.0010
# Epoch 7/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0850 - val_loss: 0.0869 - lr: 0.0010
# Epoch 8/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0853 - val_loss: 0.0842 - lr: 0.0010
# Epoch 9/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0824 - val_loss: 0.0815 - lr: 0.0010
# Epoch 10/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0794 - val_loss: 0.0800 - lr: 0.0010
# Epoch 11/100
# 6/6 [==============================] - 9s 1s/step - loss: 0.0788 - val_loss: 0.0806 - lr: 0.0010
# Epoch 12/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0795 - val_loss: 0.0835 - lr: 0.0010
# Epoch 13/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0795 - val_loss: 0.0797 - lr: 0.0010
# Epoch 14/100
# 6/6 [==============================] - 10s 2s/step - loss: 0.0774 - val_loss: 0.0783 - lr: 0.0010
# Epoch 15/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0753 - val_loss: 0.0792 - lr: 0.0010
# Epoch 16/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0770 - val_loss: 0.0794 - lr: 0.0010
# Epoch 17/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0759 - val_loss: 0.0782 - lr: 0.0010
# Epoch 18/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0741 - val_loss: 0.0776 - lr: 0.0010
# Epoch 19/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0747 - val_loss: 0.0803 - lr: 0.0010
# Epoch 20/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0760 - val_loss: 0.0781 - lr: 0.0010
# Epoch 21/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0737 - val_loss: 0.0779 - lr: 0.0010
# Epoch 22/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0734
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 6/6 [==============================] - 9s 2s/step - loss: 0.0734 - val_loss: 0.0799 - lr: 0.0010
# Epoch 23/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0738 - val_loss: 0.0777 - lr: 2.0000e-04
# Epoch 24/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0737 - val_loss: 0.0777 - lr: 2.0000e-04
# Epoch 25/100
# 6/6 [==============================] - 9s 2s/step - loss: 0.0725 - val_loss: 0.0782 - lr: 2.0000e-04
# Epoch 26/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0727Restoring model weights from the end of the best epoch: 18.
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 6/6 [==============================] - 9s 2s/step - loss: 0.0727 - val_loss: 0.0777 - lr: 2.0000e-04
# Epoch 00026: early stopping

# %%
# sayyiv le modele when done
model_lstm.save('./test_model_LSTM')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./test_model_LSTM\assets
# INFO:tensorflow:Assets written to: ./test_model_LSTM\assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002275096B520> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x000002275094DE50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# try drawing the losses and the scores just to see where we are heading towards
print(history.history.keys())

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# why not also draw out the learning rate
plt.plot(history.history['lr'])
plt.title('Learning Rate')
plt.ylabel('LR')
plt.xlabel('epoch')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'lr'])

# %%
preds = model_lstm.predict(X_test_scaled)
preds = scaler.inverse_transform(preds)
plt.rcParams["figure.figsize"] = (32,12)
TestY = pd.DataFrame(y_test)
PredY = pd.DataFrame(preds)

plot_max = plt.figure(1)
plt.plot(TestY)
plt.plot(PredY)
plt.show()

# %%
#-----------------------------------------------------------
# LETS CHECK HOW GOOD THE MODEL PERFORMED
#-----------------------------------------------------------
testScore_1 = math.sqrt(mean_squared_error(y_test[:], preds[:]))
print('Test Score: %.2f RMSE' % (testScore_1))

testScore_2 = math.sqrt(mean_absolute_error(y_test[:], preds[:]))
print('Test Score: %f MAE' % (testScore_2))

testScore_3 = np.mean(np.abs(preds - y_test)/np.abs(y_test)*100)
print('Test Score: %f MAPE' % (testScore_3))
# Out:
# Test Score: 0.06 RMSE
# Test Score: 0.189315 MAE
# Test Score: 26.734583 MAPE

# %% [markdown]
# # Let's try to implement a GRU

# %%
# let's build the lstm model
# return sequences?? -> 
model_GRU = tf.keras.models.Sequential()
model_GRU.add(tf.keras.layers.GRU(512,input_shape=(X_train.shape[1], 1),return_sequences=True))
model_GRU.add(tf.keras.layers.GRU(512, return_sequences=False))
model_GRU.add(tf.keras.layers.Dense(1))
model_GRU.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 50, 512)           791040
#
#  gru_1 (GRU)                 (None, 512)               1575936
#
#  dense_4 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 2,367,489
# Trainable params: 2,367,489
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_GRU.compile(loss="mean_absolute_error", optimizer= tf.keras.optimizers.Adam())
es = tf.keras.callbacks.EarlyStopping( monitor='val_loss', patience=8, verbose=1, restore_best_weights=True)
lr_red = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=4, verbose=1, min_lr=0.0000001,)

# %%
callbacks = [es, lr_red]
history = model_GRU.fit(X_train, y_train, epochs=100, validation_split=0.25, batch_size=256, verbose=1,
                    shuffle=False,
                    callbacks = callbacks)
# would be logical to train model on mutltiple batch sizes
# Out:
# Epoch 1/100
# 6/6 [==============================] - 11s 1s/step - loss: 0.1128 - val_loss: 0.0829 - lr: 0.0010
# Epoch 2/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0919 - val_loss: 0.1039 - lr: 0.0010
# Epoch 3/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0909 - val_loss: 0.0806 - lr: 0.0010
# Epoch 4/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0753 - val_loss: 0.0801 - lr: 0.0010
# Epoch 5/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0756 - val_loss: 0.0833 - lr: 0.0010
# Epoch 6/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0776 - val_loss: 0.0809 - lr: 0.0010
# Epoch 7/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0748 - val_loss: 0.0813 - lr: 0.0010
# Epoch 8/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0738
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 6/6 [==============================] - 8s 1s/step - loss: 0.0738 - val_loss: 0.0825 - lr: 0.0010
# Epoch 9/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0742 - val_loss: 0.0815 - lr: 2.0000e-04
# Epoch 10/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0740 - val_loss: 0.0815 - lr: 2.0000e-04
# Epoch 11/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.0735 - val_loss: 0.0819 - lr: 2.0000e-04
# Epoch 12/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0738Restoring model weights from the end of the best epoch: 4.
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 6/6 [==============================] - 9s 1s/step - loss: 0.0738 - val_loss: 0.0816 - lr: 2.0000e-04
# Epoch 00012: early stopping

# %%
preds = model_GRU.predict(X_test_scaled)
preds = scaler.inverse_transform(preds)
plt.rcParams["figure.figsize"] = (32,12)
TestY = pd.DataFrame(y_test, columns=['avg_cpu'])
PredY = pd.DataFrame(preds, columns=['avg_cpu'])

plot_avg = plt.figure(1)
plt.plot(TestY['avg_cpu'])
plt.plot(PredY['avg_cpu'])
plt.show()

# %%
# sayyiv le modele when done
model_GRU.save('./test_model_GPU')
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses, gru_cell_1_layer_call_fn, gru_cell_1_layer_call_and_return_conditional_losses, gru_cell_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./test_model_GPU\assets
# INFO:tensorflow:Assets written to: ./test_model_GPU\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x00000227031BA970> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x00000227031C9370> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
#-----------------------------------------------------------
# LETS CHECK HOW GOOD THE MODEL PERFORMED
#-----------------------------------------------------------
testScore_1 = math.sqrt(mean_squared_error(y_test[:], preds[:]))
print('Test Score: %.2f RMSE' % (testScore_1))

testScore_2 = math.sqrt(mean_absolute_error(y_test[:], preds[:]))
print('Test Score: %f MAE' % (testScore_2))

testScore_3 = np.mean(np.abs(preds - y_test)/np.abs(y_test)*100)
print('Test Score: %f MAPE' % (testScore_3))
# Out:
# Test Score: 0.06 RMSE
# Test Score: 0.189941 MAE
# Test Score: 26.237282 MAPE
